# %%
from pennylane import qaoa
import pennylane as qml
from pennylane import numpy as np
from matplotlib import pyplot as plt
import networkx as nx

# %%
edges = [(0, 1), (1, 2), (2, 0), (2, 3)]
graph = nx.Graph(edges)

nx.draw(graph, with_labels=True)
plt.show()

# %%
optimizer = qml.GradientDescentOptimizer()
steps = 70
params = np.array([[0.5, 0.5], [0.5, 0.5]], requires_grad=True)

# %%
cost_h, mixer_h = qaoa.min_vertex_cover(graph, constrained=False)

print("Cost Hamiltonian", cost_h)
print("Mixer Hamiltonian", mixer_h)
# Out:
# Cost Hamiltonian   (-0.25) [Z3]
# + (0.5) [Z0]
# + (0.5) [Z1]
# + (1.25) [Z2]
# + (0.75) [Z0 Z1]
# + (0.75) [Z0 Z2]
# + (0.75) [Z1 Z2]
# + (0.75) [Z2 Z3]
# Mixer Hamiltonian   (1) [X0]
# + (1) [X1]
# + (1) [X2]
# + (1) [X3]

# %%
def qaoa_layer(gamma, alpha):
    qaoa.cost_layer(gamma, cost_h)
    qaoa.mixer_layer(alpha, mixer_h)

# %%
wires = range(4)
depth = 2

def circuit(params, **kwargs):
    for w in wires:
        qml.Hadamard(wires=w)
    qml.layer(qaoa_layer, depth, params[0], params[1])

# %%
from functools import partial

dev = qml.device("default.qubit", wires=4, shots=100)

#@partial(qml.cut_circuit, auto_cutter=True)  # auto_cutter enabled
@qml.qnode(dev)
def cost_function(params):
    circuit(params)
    return qml.expval(cost_h)


for i in range(steps):
    params = optimizer.step(cost_function, params)
    print("Step", i, "Cost", cost_function(params))

print("Optimal Parameters")
print(params)
# Out:
# Step 0 Cost 1.4700000000000002
# Step 1 Cost 0.71
# Step 2 Cost -0.19999999999999998
# Step 3 Cost -0.4
# Step 4 Cost -0.55
# Step 5 Cost -0.45
# Step 6 Cost -0.6799999999999999
# Step 7 Cost -0.9400000000000002
# Step 8 Cost -1.24
# Step 9 Cost -1.27
# Step 10 Cost -1.0
# Step 11 Cost -1.07
# Step 12 Cost -1.4
# Step 13 Cost -1.35
# Step 14 Cost -1.3
# Step 15 Cost -1.5
# Step 16 Cost -1.6600000000000004
# Step 17 Cost -1.5099999999999998
# Step 18 Cost -1.5900000000000003
# Step 19 Cost -1.3399999999999999
# Step 20 Cost -1.2899999999999998
# Step 21 Cost -1.2400000000000002
# Step 22 Cost -1.8699999999999999
# Step 23 Cost -1.7499999999999998
# Step 24 Cost -1.34
# Step 25 Cost -1.7799999999999998
# Step 26 Cost -1.46
# Step 27 Cost -1.7100000000000002
# Step 28 Cost -1.4500000000000002
# Step 29 Cost -1.6800000000000002
# Step 30 Cost -1.59
# Step 31 Cost -1.65
# Step 32 Cost -1.41
# Step 33 Cost -1.9800000000000004
# Step 34 Cost -2.01
# Step 35 Cost -1.6300000000000001
# Step 36 Cost -1.6700000000000002
# Step 37 Cost -1.7399999999999998
# Step 38 Cost -1.34
# Step 39 Cost -1.5699999999999998
# Step 40 Cost -1.3999999999999997
# Step 41 Cost -1.9100000000000001
# Step 42 Cost -1.78
# Step 43 Cost -1.5799999999999998
# Step 44 Cost -1.79
# Step 45 Cost -1.3800000000000001
# Step 46 Cost -1.53
# Step 47 Cost -1.3000000000000003
# Step 48 Cost -1.9500000000000004
# Step 49 Cost -1.43
# Step 50 Cost -1.49
# Step 51 Cost -1.3800000000000001
# Step 52 Cost -1.7200000000000002
# Step 53 Cost -1.62
# Step 54 Cost -1.7000000000000002
# Step 55 Cost -1.1800000000000002
# Step 56 Cost -1.73
# Step 57 Cost -1.7200000000000002
# Step 58 Cost -1.7
# Step 59 Cost -1.4500000000000002
# Step 60 Cost -1.68
# Step 61 Cost -1.3800000000000001
# Step 62 Cost -1.6400000000000001
# Step 63 Cost -1.74
# Step 64 Cost -1.6199999999999999
# Step 65 Cost -1.6
# Step 66 Cost -1.6000000000000003
# Step 67 Cost -1.43
# Step 68 Cost -1.5299999999999998
# Step 69 Cost -1.49
# Optimal Parameters
# [[0.603825 0.9359  ]
#  [0.5253   0.8465  ]]

# %%
dev = qml.device("default.qubit", wires=wires, shots=100)

@qml.qnode(dev)
def probability_circuit(gamma, alpha):
    circuit([gamma, alpha])
    return qml.probs(wires=wires)


probs = probability_circuit(params[0], params[1])
qml.draw_mpl(probability_circuit)(params[0], params[1])
plt.show()
plt.bar(range(2 ** len(wires)), probs)
plt.show()

# %%
from functools import partial

steps = 10
params = np.array([[0.5, 0.5], [0.5, 0.5]], requires_grad=True)

dev = qml.device("lightning.qubit", wires=3, shots=5)

@partial(qml.cut_circuit, auto_cutter=True, use_opt_einsum=True)
@qml.qnode(dev)
def cost_function(params):
    circuit(params)
    return qml.expval(cost_h)

qml.specs(cost_function)(params)


for i in range(steps):
    params = optimizer.step(cost_function, params)
    print("Step", i, "Cost", cost_function(params))

print("Optimal Parameters")
print(params)
# Out:
# /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qcut/cutstrategy.py:367: UserWarning: The numer of partition attempts seems high (53).
#   warnings.warn(f"The numer of partition attempts seems high ({len(ks)}).")
# /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qcut/cutstrategy.py:367: UserWarning: The numer of partition attempts seems high (52).
#   warnings.warn(f"The numer of partition attempts seems high ({len(ks)}).")
# Step 0 Cost 3.182000000000002
# Step 1 Cost 7.169
# Step 2 Cost 4.751499999999998
# Step 3 Cost -6.149499999999998
# Step 4 Cost 11.508
# Step 5 Cost -1.213499999999999
# Step 6 Cost 5.157999999999996
# Step 7 Cost 8.129999999999999
# Step 8 Cost -12.962
# Step 9 Cost -5.803000000000002
# Optimal Parameters
# [[ 2.2882275   0.57188375]
#  [-0.00484    -0.161725  ]]

# %%
for i in range(steps):
    params = optimizer.step(cost_function, params)
    print("Step", i, "Cost", cost_function(params))

print("Optimal Parameters")
print(params)

# %%
from functools import partial

n_qubit = 4

dev = qml.device("default.qubit", wires=4, shots=1000)

@partial(qml.cut_circuit_mc, auto_cutter=True)  # auto_cutter enabled
@qml.qnode(dev)
def probability_circuit(gamma, alpha):
    circuit([gamma, alpha])
    return qml.sample(wires=wires)

res = probability_circuit(params[0], params[1])

bitstrings = ["{0:0{1}b}".format(i, n_qubit) for i in range(2**n_qubit)]

probs = []

str_res = []

for r in res:
    str_res.append("".join([str(int(i)) for i in r]))

for b in bitstrings:
    probs.append(str_res.count(b) / len(res))

print(f"Probability of measuring each state: {probs}")
plt.bar(range(2 ** n_qubit), probs)
# Out:
# /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qcut/cutstrategy.py:367: UserWarning: The numer of partition attempts seems high (55).
#   warnings.warn(f"The numer of partition attempts seems high ({len(ks)}).")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 13
#      10     circuit([gamma, alpha])
#      11     return qml.sample(wires=wires)
# ---> 13 res = probability_circuit(params[0], params[1])
#      15 bitstrings = ["{0:0{1}b}".format(i, n_qubit) for i in range(2**n_qubit)]
#      17 probs = []
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qcut/cutcircuit_mc.py:522, in CustomQNode.__call__(self, *args, **kwargs)
#     519 qcut_tc._kwargs["shots"] = shots
#     521 kwargs["shots"] = 1
# --> 522 return super().__call__(*args, **kwargs)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qnode.py:1039, in QNode.__call__(self, *args, **kwargs)
#    1034         full_transform_program._set_all_argnums(
#    1035             self, args, kwargs, argnums
#    1036         )  # pylint: disable=protected-access
#    1038 # pylint: disable=unexpected-keyword-arg
# -> 1039 res = qml.execute(
#    1040     (self._tape,),
#    1041     device=self.device,
#    1042     gradient_fn=self.gradient_fn,
#    1043     interface=self.interface,
#    1044     transform_program=full_transform_program,
#    1045     config=config,
#    1046     gradient_kwargs=self.gradient_kwargs,
#    1047     override_shots=override_shots,
#    1048     **self.execute_kwargs,
#    1049 )
#    1051 res = res[0]
#    1053 # convert result to the interface in case the qfunc has no parameters
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/interfaces/execution.py:632, in execute(tapes, device, gradient_fn, interface, transform_program, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform, device_vjp)
#     627     if not device_batch_transform:
#     628         warnings.warn(
#     629             "device batch transforms cannot be turned off with the new device interface.",
#     630             UserWarning,
#     631         )
# --> 632     tapes, post_processing = transform_program(tapes)
#     633 else:
#     634     # TODO: Remove once old device are removed
#     635     tapes, program_post_processing = transform_program(tapes)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/transforms/core/transform_program.py:435, in TransformProgram.__call__(self, tapes)
#     433 if self._argnums is not None and self._argnums[i] is not None:
#     434     tape.trainable_params = self._argnums[i][j]
# --> 435 new_tapes, fn = transform(tape, *targs, **tkwargs)
#     436 execution_tapes.extend(new_tapes)
#     438 fns.append(fn)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qcut/cutcircuit_mc.py:452, in cut_circuit_mc(tape, classical_processing_fn, auto_cutter, max_depth, shots, device_wires, **kwargs)
#     447 if auto_cutter is True or callable(auto_cutter):
#     448     cut_strategy = kwargs.pop("cut_strategy", None) or CutStrategy(
#     449         max_free_wires=len(device_wires)
#     450     )
# --> 452     g = find_and_place_cuts(
#     453         graph=g,
#     454         cut_method=auto_cutter if callable(auto_cutter) else kahypar_cut,
#     455         cut_strategy=cut_strategy,
#     456         **kwargs,
#     457     )
#     459 replace_wire_cut_nodes(g)
#     460 fragments, communication_graph = fragment_graph(g)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qcut/utils.py:282, in find_and_place_cuts(graph, cut_method, cut_strategy, replace_wire_cuts, local_measurement, **kwargs)
#     279 seed = kwargs.pop("seed", None)
#     280 seeds = np.random.default_rng(seed).choice(2**15, cut_strategy.trials_per_probe).tolist()
# --> 282 cut_edges_probed = {
#     283     (cut_kwargs["num_fragments"], trial_id): cut_method(
#     284         cut_graph,
#     285         **{
#     286             **cut_kwargs,
#     287             **kwargs,
#     288             "seed": seed,
#     289         },  # kwargs has higher precedence for colliding keys
#     290     )
#     291     for cut_kwargs in cut_kwargs_probed
#     292     for trial_id, seed in zip(range(cut_strategy.trials_per_probe), seeds)
#     293 }
#     295 valid_cut_edges = {}
#     296 for (num_partitions, _), cut_edges in cut_edges_probed.items():
#     297     # The easiest way to tell if a cut is valid is to just do the fragment graph.
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qcut/utils.py:283, in <dictcomp>(.0)
#     279 seed = kwargs.pop("seed", None)
#     280 seeds = np.random.default_rng(seed).choice(2**15, cut_strategy.trials_per_probe).tolist()
#     282 cut_edges_probed = {
# --> 283     (cut_kwargs["num_fragments"], trial_id): cut_method(
#     284         cut_graph,
#     285         **{
#     286             **cut_kwargs,
#     287             **kwargs,
#     288             "seed": seed,
#     289         },  # kwargs has higher precedence for colliding keys
#     290     )
#     291     for cut_kwargs in cut_kwargs_probed
#     292     for trial_id, seed in zip(range(cut_strategy.trials_per_probe), seeds)
#     293 }
#     295 valid_cut_edges = {}
#     296 for (num_partitions, _), cut_edges in cut_edges_probed.items():
#     297     # The easiest way to tell if a cut is valid is to just do the fragment graph.
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qcut/kahypar.py:153, in kahypar_cut(graph, num_fragments, imbalance, edge_weights, node_weights, fragment_weights, hyperwire_weight, seed, config_path, trial, verbose)
#     150 kahypar_seed = np.random.default_rng(seed).choice(2**15)
#     151 context.setSeed(kahypar_seed)
# --> 153 kahypar.partition(hypergraph, context)
#     155 cut_edge_mask = [hypergraph.connectivity(e) > 1 for e in hypergraph.edges()]
#     157 # compress() ignores the extra hyperwires at the end if there is any.
#
# KeyboardInterrupt:
