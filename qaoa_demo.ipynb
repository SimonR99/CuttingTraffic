# %%
import pennylane as qml
from pennylane import numpy as np
import networkx as nx
from itertools import product, combinations
from functools import partial
import matplotlib.pyplot as plt

# %%
np.random.seed(1337)

n_side_nodes = 2
n_middle_nodes = 3

top_nodes = range(0, n_side_nodes)
middle_nodes = range(n_side_nodes, n_side_nodes + n_middle_nodes)
bottom_nodes = range(n_side_nodes + n_middle_nodes, n_middle_nodes + 2 * n_side_nodes)

top_edges = list(product(top_nodes, middle_nodes))
bottom_edges = list(product(middle_nodes, bottom_nodes))

graph = nx.Graph()
graph.add_edges_from(combinations(top_nodes, 2), color=0)
graph.add_edges_from(top_edges, color=0)
graph.add_edges_from(bottom_edges, color=1)
graph.add_edges_from(combinations(bottom_nodes, 2), color=1)

nx.draw_spring(graph, with_labels=True)

# %%
all_wires = list(range(len(graph)))

dev = qml.device("default.qubit", wires=5)


optimal_params = np.array([-0.240, 0.327])
optimal_cost = -0.248

def qaoa_template(params):

    gamma, beta = params

    for i in range(len(graph)):  # Apply the Hadamard gates
        qml.Hadamard(wires=i)

    for i, j in top_edges:

        # Apply the ZZ rotation gates
        # corresponding to the
        # green edges in the figure

        qml.MultiRZ(2 * gamma, wires=[i, j])

    qml.WireCut(wires=middle_nodes)  # Place the wire cut

    for i, j in bottom_edges:

        # Apply the ZZ rotation gates
        # corresponding to the
        # purple edges in the figure

        qml.MultiRZ(2 * gamma, wires=[i, j])

    for i in graph.nodes():  # Finally, apply the RX gates
        qml.RX(2 * beta, wires=i)

def qaoa_cost(bitstring):
    #print(bitstring)

    bitstring = np.atleast_2d(bitstring)
    # Make sure that we operate correctly on a batch of bitstrings

    z = (-1) ** bitstring[:, graph.edges()]  # Filter out pairs of bits correspondimg to graph edges
    costs = z.prod(axis=-1).sum(axis=-1)  # Do products and sums
    #print(np.squeeze(costs) / len(graph.edges))
    return np.squeeze(costs) / len(graph.edges)  # Normalize

@partial(qml.cut_circuit_mc, classical_processing_fn=qaoa_cost)
@qml.qnode(dev)
def qaoa(params):
    qaoa_template(params)
    return qml.sample(wires=all_wires)

n_shots = 50

shot_counts = np.logspace(1, 2, num=5, dtype=int, requires_grad=False)
pauli_cost_values = np.zeros_like(shot_counts, dtype=float)


for i, shots in enumerate(shot_counts):
    print(qaoa(optimal_params, shots=shots))
    pauli_cost_values[i] = qaoa(optimal_params, shots=shots)

fig, ax = plt.subplots(figsize=(12, 6))

ax.semilogx(
    shot_counts,
    pauli_cost_values,
    "o-",
    c="darkorange",
    ms=8,
    markeredgecolor="k",
    label="Pauli",
)

ax.axhline(optimal_cost, color="k", linestyle="--", label="Exact value")

ax.tick_params(axis="x", labelsize=18)
ax.tick_params(axis="y", labelsize=18)

ax.set_ylabel("QAOA cost", fontsize=20)
ax.set_xlabel("Number of shots", fontsize=20)

_ = ax.legend(frameon=True, loc="lower right", fontsize=20)
# Out:
# -5.485714285714286
# 0.5378151260504201
# -0.29493087557603687
# -0.6530612244897959
# 0.36571428571428577

# %%
all_wires = list(range(len(graph)))

#dev = qml.device("default.qubit", wires=all_wires)
dev = qml.device("alicebob.qubit", alice_backend="EMU:40Q:LOGICAL_TARGET", wires=7, average_nb_photons=8, kappa_1=10, kappa_2=1e8, shots=100)

optimal_params = np.array([-0.240, 0.327])
optimal_cost = -0.248

def qaoa_template(params):

    gamma, beta = params

    for i in range(len(graph)):  # Apply the Hadamard gates
        qml.Hadamard(wires=i)

    for i, j in top_edges:

        # Apply the ZZ rotation gates
        # corresponding to the
        # green edges in the figure

        qml.MultiRZ(2 * gamma, wires=[i, j])

    qml.WireCut(wires=middle_nodes)  # Place the wire cut

    for i, j in bottom_edges:

        # Apply the ZZ rotation gates
        # corresponding to the
        # purple edges in the figure

        qml.MultiRZ(2 * gamma, wires=[i, j])

    for i in graph.nodes():  # Finally, apply the RX gates
        qml.RX(2 * beta, wires=i)

def qaoa_cost(bitstring):

    bitstring = np.atleast_2d(bitstring)
    # Make sure that we operate correctly on a batch of bitstrings

    z = (-1) ** bitstring[:, graph.edges()]  # Filter out pairs of bits correspondimg to graph edges
    costs = z.prod(axis=-1).sum(axis=-1)  # Do products and sums
    return np.squeeze(costs) / len(graph.edges)  # Normalize

@partial(qml.cut_circuit_mc, classical_processing_fn=qaoa_cost)
@qml.qnode(dev)
def qaoa(params):
    qaoa_template(params)
    return qml.sample(wires=all_wires)

n_shots = 50

shot_counts = np.logspace(1, 2, num=3, dtype=int, requires_grad=False)
pauli_cost_values = np.zeros_like(shot_counts, dtype=float)

for i, shots in enumerate(shot_counts):
    pauli_cost_values[i] = qaoa(optimal_params, shots=shots)

fig, ax = plt.subplots(figsize=(12, 6))

ax.semilogx(
    shot_counts,
    pauli_cost_values,
    "o-",
    c="darkorange",
    ms=8,
    markeredgecolor="k",
    label="Pauli",
)

ax.axhline(optimal_cost, color="k", linestyle="--", label="Exact value")

ax.tick_params(axis="x", labelsize=18)
ax.tick_params(axis="y", labelsize=18)

ax.set_ylabel("QAOA cost", fontsize=20)
ax.set_xlabel("Number of shots", fontsize=20)

_ = ax.legend(frameon=True, loc="lower right", fontsize=20)
# Out:
# Using alice & bob EMU:40Q:LOGICAL_TARGET backend...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 58
#      55 pauli_cost_values = np.zeros_like(shot_counts, dtype=float)
#      57 for i, shots in enumerate(shot_counts):
# ---> 58     pauli_cost_values[i] = qaoa(optimal_params, shots=shots)
#      60 fig, ax = plt.subplots(figsize=(12, 6))
#      62 ax.semilogx(
#      63     shot_counts,
#      64     pauli_cost_values,
#    (...)
#      69     label="Pauli",
#      70 )
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qcut/cutcircuit_mc.py:522, in CustomQNode.__call__(self, *args, **kwargs)
#     519 qcut_tc._kwargs["shots"] = shots
#     521 kwargs["shots"] = 1
# --> 522 return super().__call__(*args, **kwargs)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/qnode.py:1039, in QNode.__call__(self, *args, **kwargs)
#    1034         full_transform_program._set_all_argnums(
#    1035             self, args, kwargs, argnums
#    1036         )  # pylint: disable=protected-access
#    1038 # pylint: disable=unexpected-keyword-arg
# -> 1039 res = qml.execute(
#    1040     (self._tape,),
#    1041     device=self.device,
#    1042     gradient_fn=self.gradient_fn,
#    1043     interface=self.interface,
#    1044     transform_program=full_transform_program,
#    1045     config=config,
#    1046     gradient_kwargs=self.gradient_kwargs,
#    1047     override_shots=override_shots,
#    1048     **self.execute_kwargs,
#    1049 )
#    1051 res = res[0]
#    1053 # convert result to the interface in case the qfunc has no parameters
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/interfaces/execution.py:808, in execute(tapes, device, gradient_fn, interface, transform_program, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform, device_vjp)
#     803 ml_boundary_execute = _get_ml_boundary_execute(
#     804     interface, _grad_on_execution, config.use_device_jacobian_product
#     805 )
#     807 if interface in jpc_interfaces:
# --> 808     results = ml_boundary_execute(tapes, execute_fn, jpc, device=device)
#     809 else:
#     810     results = ml_boundary_execute(
#     811         tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n=1, max_diff=max_diff
#     812     )
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/interfaces/autograd.py:147, in autograd_execute(tapes, execute_fn, jpc, device)
#     142 # pylint misidentifies autograd.builtins as a dict
#     143 # pylint: disable=no-member
#     144 parameters = autograd.builtins.tuple(
#     145     [autograd.builtins.list(t.get_parameters()) for t in tapes]
#     146 )
# --> 147 return _execute(parameters, tuple(tapes), execute_fn, jpc)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/autograd/tracer.py:48, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      46     return new_box(ans, trace, node)
#      47 else:
# ---> 48     return f_raw(*args, **kwargs)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/interfaces/autograd.py:168, in _execute(parameters, tapes, execute_fn, jpc)
#     150 @autograd.extend.primitive
#     151 def _execute(
#     152     parameters,
#    (...)
#     155     jpc,
#     156 ):  # pylint: disable=unused-argument
#     157     """Autodifferentiable wrapper around a way of executing tapes.
#     158
#     159     Args:
#    (...)
#     166
#     167     """
# --> 168     return execute_fn(tapes)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/interfaces/execution.py:261, in _make_inner_execute.<locals>.inner_execute(tapes, **_)
#     259 if numpy_only:
#     260     tapes = tuple(qml.transforms.convert_to_numpy_parameters(t) for t in tapes)
# --> 261 return cached_device_execution(tapes)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane/interfaces/execution.py:335, in cache_execute.<locals>.wrapper(tapes, **kwargs)
#     328     kwargs = {}
#     330 if cache is None or (isinstance(cache, bool) and not cache):
#     331     # No caching. Simply execute the execution function
#     332     # and return the results.
#     333
#     334     # must convert to list as new device interface returns tuples
# --> 335     res = list(fn(tapes, **kwargs))
#     336     return (res, []) if return_tuple else res
#     338 execution_tapes = {}
#
# File /usr/local/python/3.11.8/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane_qiskit/qiskit_device.py:495, in QiskitDevice.batch_execute(self, circuits, timeout)
#     492 def batch_execute(self, circuits, timeout: int = None):
#     493     # pylint: disable=missing-function-docstring
# --> 495     compiled_circuits = self.compile_circuits(circuits)
#     497     # Send the batch of circuit objects using backend.run
#     498     self._current_job = self.backend.run(compiled_circuits, shots=self.shots, **self.run_args)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane_qiskit/qiskit_device.py:486, in QiskitDevice.compile_circuits(self, circuits)
#     483 self.reset()
#     484 self.create_circuit_object(circuit.operations, rotations=circuit.diagonalizing_gates)
# --> 486 compiled_circ = self.compile()
#     487 compiled_circ.name = f"circ{len(compiled_circuits)}"
#     488 compiled_circuits.append(compiled_circ)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/pennylane_qiskit/qiskit_device.py:396, in QiskitDevice.compile(self)
#     390 """Compile the quantum circuit to target the provided compile_backend.
#     391
#     392 If compile_backend is None, then the target is simply the
#     393 backend.
#     394 """
#     395 compile_backend = self.compile_backend or self.backend
# --> 396 compiled_circuits = transpile(self._circuit, backend=compile_backend, **self.transpile_args)
#     397 return compiled_circuits
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/compiler/transpiler.py:419, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     391         instruction_durations = _parse_instruction_durations(
#     392             backend, instruction_durations, dt, circuits[0]
#     393         )
#     395 pm = generate_preset_pass_manager(
#     396     optimization_level,
#     397     backend=backend,
#    (...)
#     417     _skip_target=_skip_target,
#     418 )
# --> 419 out_circuits = pm.run(circuits, callback=callback)
#     420 for name, circ in zip(output_name, out_circuits):
#     421     circ.name = name
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/transpiler/passmanager.py:537, in StagedPassManager.run(self, circuits, output_name, callback)
#     530 def run(
#     531     self,
#     532     circuits: _CircuitsT,
#     533     output_name: str | None = None,
#     534     callback: Callable | None = None,
#     535 ) -> _CircuitsT:
#     536     self._update_passmanager()
# --> 537     return super().run(circuits, output_name, callback)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/transpiler/passmanager.py:233, in PassManager.run(self, circuits, output_name, callback)
#     231     return self._run_single_circuit(circuits, output_name, callback)
#     232 if len(circuits) == 1:
# --> 233     return [self._run_single_circuit(circuits[0], output_name, callback)]
#     234 return self._run_several_circuits(circuits, output_name, callback)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/transpiler/passmanager.py:292, in PassManager._run_single_circuit(self, circuit, output_name, callback)
#     280 """Run all the passes on a ``circuit``.
#     281
#     282 Args:
#    (...)
#     289     The transformed circuit.
#     290 """
#     291 running_passmanager = self._create_running_passmanager()
# --> 292 result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     293 self.property_set = running_passmanager.property_set
#     294 return result
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/transpiler/runningpassmanager.py:125, in RunningPassManager.run(***failed resolving arguments***)
#     123 for passset in self.working_list:
#     124     for pass_ in passset:
# --> 125         dag = self._do_pass(pass_, dag, passset.options)
#     127 circuit = dag_to_circuit(dag, copy_operations=False)
#     128 if output_name:
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/transpiler/runningpassmanager.py:173, in RunningPassManager._do_pass(self, pass_, dag, options)
#     171 # Run the pass itself, if not already run
#     172 if pass_ not in self.valid_passes:
# --> 173     dag = self._run_this_pass(pass_, dag)
#     175     # update the valid_passes property
#     176     self._update_valid_passes(pass_)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/transpiler/runningpassmanager.py:202, in RunningPassManager._run_this_pass(self, pass_, dag)
#     199 if pass_.is_transformation_pass:
#     200     # Measure time if we have a callback or logging set
#     201     start_time = time()
# --> 202     new_dag = pass_.run(dag)
#     203     end_time = time()
#     204     run_time = end_time - start_time
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/transpiler/passes/synthesis/unitary_synthesis.py:450, in UnitarySynthesis.run(self, dag)
#     443     plugin_method._approximation_degree = self._approximation_degree
#     445 qubit_indices = (
#     446     {bit: i for i, bit in enumerate(dag.qubits)}
#     447     if plugin_method.supports_coupling_map or default_method.supports_coupling_map
#     448     else {}
#     449 )
# --> 450 return self._run_main_loop(
#     451     dag, qubit_indices, plugin_method, plugin_kwargs, default_method, default_kwargs
#     452 )
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/transpiler/passes/synthesis/unitary_synthesis.py:496, in UnitarySynthesis._run_main_loop(self, dag, qubit_indices, plugin_method, plugin_kwargs, default_method, default_kwargs)
#     491 if method.supports_coupling_map:
#     492     kwargs["coupling_map"] = (
#     493         self._coupling_map,
#     494         [qubit_indices[x] for x in node.qargs],
#     495     )
# --> 496 synth_dag = method.run(unitary, **kwargs)
#     497 if synth_dag is not None:
#     498     dag.substitute_node_with_dag(node, synth_dag)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/transpiler/passes/synthesis/solovay_kitaev_synthesis.py:287, in SolovayKitaevSynthesis.run(self, unitary, **options)
#     283         basic_approximations = generate_basic_approximations(basis_gates, depth)
#     285     SolovayKitaevSynthesis._sk = SolovayKitaevDecomposition(basic_approximations)
# --> 287 approximate_circuit = SolovayKitaevSynthesis._sk.run(unitary, recursion_degree)
#     288 dag_circuit = circuit_to_dag(approximate_circuit)
#     289 return dag_circuit
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/synthesis/discrete_basis/solovay_kitaev.py:113, in SolovayKitaevDecomposition.run(self, gate_matrix, recursion_degree, return_dag, check_input)
#     110 global_phase = np.arctan2(np.imag(z), np.real(z))
#     112 # get the decompositon as GateSequence type
# --> 113 decomposition = self._recurse(gate_matrix_su2, recursion_degree, check_input=check_input)
#     115 # simplify
#     116 _remove_identities(decomposition)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/synthesis/discrete_basis/solovay_kitaev.py:150, in SolovayKitaevDecomposition._recurse(self, sequence, n, check_input)
#     147 if n == 0:
#     148     return self.find_basic_approximation(sequence)
# --> 150 u_n1 = self._recurse(sequence, n - 1, check_input=check_input)
#     152 v_n, w_n = commutator_decompose(
#     153     sequence.dot(u_n1.adjoint()).product, check_input=check_input
#     154 )
#     156 v_n1 = self._recurse(v_n, n - 1, check_input=check_input)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/synthesis/discrete_basis/solovay_kitaev.py:150, in SolovayKitaevDecomposition._recurse(self, sequence, n, check_input)
#     147 if n == 0:
#     148     return self.find_basic_approximation(sequence)
# --> 150 u_n1 = self._recurse(sequence, n - 1, check_input=check_input)
#     152 v_n, w_n = commutator_decompose(
#     153     sequence.dot(u_n1.adjoint()).product, check_input=check_input
#     154 )
#     156 v_n1 = self._recurse(v_n, n - 1, check_input=check_input)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/synthesis/discrete_basis/solovay_kitaev.py:158, in SolovayKitaevDecomposition._recurse(self, sequence, n, check_input)
#     156 v_n1 = self._recurse(v_n, n - 1, check_input=check_input)
#     157 w_n1 = self._recurse(w_n, n - 1, check_input=check_input)
# --> 158 return v_n1.dot(w_n1).dot(v_n1.adjoint()).dot(w_n1.adjoint()).dot(u_n1)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/synthesis/discrete_basis/gate_sequence.py:170, in GateSequence.adjoint(self)
#     167 """Get the complex conjugate."""
#     168 # We're initializing an empty GateSequence and set the state manually, as we can
#     169 # efficiently infer the adjoint values from the current value instead of recomputing them.
# --> 170 adjoint = GateSequence()
#     171 adjoint.gates = [gate.inverse() for gate in reversed(self.gates)]
#     172 adjoint.labels = [inv.name for inv in adjoint.gates]
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/synthesis/discrete_basis/gate_sequence.py:48, in GateSequence.__init__(self, gates)
#      45     u2_matrix = matrix.dot(u2_matrix)
#      47 # convert to SU(2)
# ---> 48 su2_matrix, global_phase = _convert_u2_to_su2(u2_matrix)
#      50 # convert to SO(3), that's what the Solovay Kitaev algorithm uses
#      51 so3_matrix = _convert_su2_to_so3(su2_matrix)
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/qiskit/synthesis/discrete_basis/gate_sequence.py:294, in _convert_u2_to_su2(u2_matrix)
#     292 def _convert_u2_to_su2(u2_matrix: np.ndarray) -> tuple[np.ndarray, float]:
#     293     """Convert a U(2) matrix to SU(2) by adding a global phase."""
# --> 294     z = 1 / np.sqrt(np.linalg.det(u2_matrix))
#     295     su2_matrix = z * u2_matrix
#     296     phase = np.arctan2(np.imag(z), np.real(z))
#
# File /usr/local/python/3.11.8/lib/python3.11/site-packages/numpy/linalg/linalg.py:2175, in det(a)
#    2126 @array_function_dispatch(_unary_dispatcher)
#    2127 def det(a):
#    2128     """
#    2129     Compute the determinant of an array.
#    2130
#    (...)
#    2173
#    2174     """
# -> 2175     a = asarray(a)
#    2176     _assert_stacked_2d(a)
#    2177     _assert_stacked_square(a)
#
# KeyboardInterrupt:

# %%
all_wires = list(range(len(graph)))

dev = qml.device("default.mixed", wires=8, shots=1000)


optimal_params = np.array([-0.240, 0.327])
optimal_cost = -0.248

def qaoa_template(params):

    gamma, beta = params

    for i in range(len(graph)):  # Apply the Hadamard gates
        qml.Hadamard(wires=i)

    for i, j in top_edges:

        # Apply the ZZ rotation gates
        # corresponding to the
        # green edges in the figure

        qml.MultiRZ(2 * gamma, wires=[i, j])

    qml.WireCut(wires=middle_nodes)  # Place the wire cut

    for i, j in bottom_edges:

        # Apply the ZZ rotation gates
        # corresponding to the
        # purple edges in the figure

        qml.MultiRZ(2 * gamma, wires=[i, j])

    for i in graph.nodes():  # Finally, apply the RX gates
        qml.RX(2 * beta, wires=i)

def qaoa_cost(bitstring):

    bitstring = np.atleast_2d(bitstring)
    # Make sure that we operate correctly on a batch of bitstrings

    z = (-1) ** bitstring[:, graph.edges()]  # Filter out pairs of bits correspondimg to graph edges
    costs = z.prod(axis=-1).sum(axis=-1)  # Do products and sums
    return np.squeeze(costs) / len(graph.edges)  # Normalize

#@partial(qml.cut_circuit_mc, classical_processing_fn=qaoa_cost)
@qml.qnode(dev)
def qaoa(params):
    qaoa_template(params)
    return qml.sample()

n_shots = 50

shot_counts = np.logspace(1, 2, num=5, dtype=int, requires_grad=False)
pauli_cost_values = np.zeros_like(shot_counts, dtype=float)


arr = []
for i in qaoa(optimal_params):
    #print(qaoa_cost(i))
    arr.append(qaoa_cost(i))


print(np.sum(arr))

for i, shots in enumerate(shot_counts):
    pauli_cost_values[i] = np.sum(qaoa_cost(qaoa(optimal_params)))

fig, ax = plt.subplots(figsize=(12, 6))

ax.semilogx(
    shot_counts,
    pauli_cost_values,
    "o-",
    c="darkorange",
    ms=8,
    markeredgecolor="k",
    label="Pauli",
)

ax.axhline(optimal_cost, color="k", linestyle="--", label="Exact value")

ax.tick_params(axis="x", labelsize=18)
ax.tick_params(axis="y", labelsize=18)

ax.set_ylabel("QAOA cost", fontsize=20)
ax.set_xlabel("Number of shots", fontsize=20)

_ = ax.legend(frameon=True, loc="lower right", fontsize=20)
# Out:
# -270.57142857142856
